# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### q1

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Data Science/IoTBotNetDataset.csv")
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (7,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0            1.0  1.528089e+09     e          1.0   tcp           1.0
# 1            2.0  1.528089e+09     e          1.0   arp           2.0
# 2            3.0  1.528089e+09     e          1.0   UDP           1.0
# 3            4.0  1.528089e+09     i          1.0   tcp           1.0
# 4            5.0  1.528089e+09     e          1.0   UDP           1.0
# ...          ...           ...   ...          ...   ...           ...
# 998548  998549.0  1.528085e+09     e          1.0   udp           3.0
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# 998551  998552.0  1.528085e+09     e          1.0   udp           3.0
# 998552  998553.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr  sport            daddr dport  ...  \
# 0       192.168.100.147  49960    192.168.100.7    80  ...
# 1         192.168.100.7     -1  192.168.100.147    -1  ...
# 2       192.168.100.147  49962    192.168.100.7    80  ...
# 3       192.168.100.147  49964    192.168.100.7    80  ...
# 4       192.168.100.147  49966    192.168.100.7    80  ...
# ...                 ...    ...              ...   ...  ...
# 998548  192.168.100.149  24881    192.168.100.5    80  ...
# 998549  192.168.100.149  24882    192.168.100.5    80  ...
# 998550  192.168.100.149  24883    192.168.100.5    80  ...
# 998551  192.168.100.149  24884    192.168.100.5    80  ...
# 998552  192.168.100.149  24885    192.168.100.5    80  ...
#
#         AR_P_Proto_P_DstIP  N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  \
# 0                 1.127040               96.0              75.0
# 1             15267.200000                1.0               2.0
# 2                 1.127040               96.0              75.0
# 3                 1.127040               96.0              75.0
# 4                 1.127040               96.0              75.0
# ...                    ...                ...               ...
# 998548            0.269102              100.0             100.0
# 998549            0.269102              100.0             100.0
# 998550            0.269102              100.0             100.0
# 998551            0.269102              100.0             100.0
# 998552            0.269102              100.0             100.0
#
#         AR_P_Proto_P_Sport  AR_P_Proto_P_Dport  \
# 0                 1.133720            1.129970
# 1                 0.005142            0.005142
# 2                 1.135100            1.129970
# 3                 1.135140            1.129970
# 4                 1.135260            1.129970
# ...                    ...                 ...
# 998548            0.269107            0.269102
# 998549            0.269107            0.269102
# 998550            0.269107            0.269102
# 998551            0.269107            0.269102
# 998552            0.269107            0.269102
#
#         Pkts_P_State_P_Protocol_P_DestIP  Pkts_P_State_P_Protocol_P_SrcIP  \
# 0                                  770.0                            602.0
# 1                                    2.0                              6.0
# 2                                  770.0                            602.0
# 3                                  770.0                            602.0
# 4                                  770.0                            602.0
# ...                                  ...                              ...
# 998548                             700.0                            700.0
# 998549                             700.0                            700.0
# 998550                             700.0                            700.0
# 998551                             700.0                            700.0
# 998552                             700.0                            700.0
#
#         attack  category  subcategory
# 0          1.0       DoS         HTTP
# 1          1.0       DoS         HTTP
# 2          1.0       DoS         HTTP
# 3          1.0       DoS         HTTP
# 4          1.0       DoS         HTTP
# ...        ...       ...          ...
# 998548     1.0       DoS          UDP
# 998549     1.0       DoS          UDP
# 998550     1.0       DoS          UDP
# 998551     1.0       DoS          UDP
# 998552     1.0       DoS          UDP
#
# [998553 rows x 46 columns]

# %% [markdown]
# ### q2

# %%
df.drop(["stime"],axis=1)
# Out:
#          pkSeqID flags  flgs_number proto  proto_number            saddr  \
# 0            1.0     e          1.0   tcp           1.0  192.168.100.147
# 1            2.0     e          1.0   arp           2.0    192.168.100.7
# 2            3.0     e          1.0   UDP           1.0  192.168.100.147
# 3            4.0     i          1.0   tcp           1.0  192.168.100.147
# 4            5.0     e          1.0   UDP           1.0  192.168.100.147
# ...          ...   ...          ...   ...           ...              ...
# 998548  998549.0     e          1.0   udp           3.0  192.168.100.149
# 998549  998550.0     e          1.0   udp           3.0  192.168.100.149
# 998550  998551.0     e          1.0   udp           3.0  192.168.100.149
# 998551  998552.0     e          1.0   udp           3.0  192.168.100.149
# 998552  998553.0     e          1.0   udp           3.0  192.168.100.149
#
#         sport            daddr dport  pkts  ...  AR_P_Proto_P_DstIP  \
# 0       49960    192.168.100.7    80   8.0  ...            1.127040
# 1          -1  192.168.100.147    -1   2.0  ...        15267.200000
# 2       49962    192.168.100.7    80   8.0  ...            1.127040
# 3       49964    192.168.100.7    80   8.0  ...            1.127040
# 4       49966    192.168.100.7    80   8.0  ...            1.127040
# ...       ...              ...   ...   ...  ...                 ...
# 998548  24881    192.168.100.5    80   7.0  ...            0.269102
# 998549  24882    192.168.100.5    80   7.0  ...            0.269102
# 998550  24883    192.168.100.5    80   7.0  ...            0.269102
# 998551  24884    192.168.100.5    80   7.0  ...            0.269102
# 998552  24885    192.168.100.5    80   7.0  ...            0.269102
#
#        N_IN_Conn_P_DstIP  N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 0                   96.0               75.0            1.133720
# 1                    1.0                2.0            0.005142
# 2                   96.0               75.0            1.135100
# 3                   96.0               75.0            1.135140
# 4                   96.0               75.0            1.135260
# ...                  ...                ...                 ...
# 998548             100.0              100.0            0.269107
# 998549             100.0              100.0            0.269107
# 998550             100.0              100.0            0.269107
# 998551             100.0              100.0            0.269107
# 998552             100.0              100.0            0.269107
#
#         AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 0                 1.129970                             770.0
# 1                 0.005142                               2.0
# 2                 1.129970                             770.0
# 3                 1.129970                             770.0
# 4                 1.129970                             770.0
# ...                    ...                               ...
# 998548            0.269102                             700.0
# 998549            0.269102                             700.0
# 998550            0.269102                             700.0
# 998551            0.269102                             700.0
# 998552            0.269102                             700.0
#
#         Pkts_P_State_P_Protocol_P_SrcIP  attack  category  subcategory
# 0                                 602.0     1.0       DoS         HTTP
# 1                                   6.0     1.0       DoS         HTTP
# 2                                 602.0     1.0       DoS         HTTP
# 3                                 602.0     1.0       DoS         HTTP
# 4                                 602.0     1.0       DoS         HTTP
# ...                                 ...     ...       ...          ...
# 998548                            700.0     1.0       DoS          UDP
# 998549                            700.0     1.0       DoS          UDP
# 998550                            700.0     1.0       DoS          UDP
# 998551                            700.0     1.0       DoS          UDP
# 998552                            700.0     1.0       DoS          UDP
#
# [998553 rows x 45 columns]

# %% [markdown]
# ### q3

# %%
df.isnull() #It will show True if the value in that particular cell is null
# Out:
#         pkSeqID  stime  flags  flgs_number  proto  proto_number  saddr  sport  \
# 0         False  False  False        False  False         False  False  False
# 1         False  False  False        False  False         False  False  False
# 2         False  False  False        False  False         False  False  False
# 3         False  False  False        False  False         False  False  False
# 4         False  False  False        False  False         False  False  False
# ...         ...    ...    ...          ...    ...           ...    ...    ...
# 998548    False  False  False        False  False         False  False  False
# 998549    False  False  False        False  False         False  False  False
# 998550    False  False  False        False  False         False  False  False
# 998551    False  False  False        False  False         False  False  False
# 998552    False  False  False        False  False         False  False  False
#
#         daddr  dport  ...  AR_P_Proto_P_DstIP  N_IN_Conn_P_DstIP  \
# 0       False  False  ...               False              False
# 1       False  False  ...               False              False
# 2       False  False  ...               False              False
# 3       False  False  ...               False              False
# 4       False  False  ...               False              False
# ...       ...    ...  ...                 ...                ...
# 998548  False  False  ...               False              False
# 998549  False  False  ...               False              False
# 998550  False  False  ...               False              False
# 998551  False  False  ...               False              False
# 998552  False  False  ...               False              False
#
#         N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  AR_P_Proto_P_Dport  \
# 0                   False               False               False
# 1                   False               False               False
# 2                   False               False               False
# 3                   False               False               False
# 4                   False               False               False
# ...                   ...                 ...                 ...
# 998548              False               False               False
# 998549              False               False               False
# 998550              False               False               False
# 998551              False               False               False
# 998552              False               False               False
#
#         Pkts_P_State_P_Protocol_P_DestIP  Pkts_P_State_P_Protocol_P_SrcIP  \
# 0                                  False                            False
# 1                                  False                            False
# 2                                  False                            False
# 3                                  False                            False
# 4                                  False                            False
# ...                                  ...                              ...
# 998548                             False                            False
# 998549                             False                            False
# 998550                             False                            False
# 998551                             False                            False
# 998552                             False                            False
#
#         attack  category  subcategory
# 0        False     False        False
# 1        False     False        False
# 2        False     False        False
# 3        False     False        False
# 4        False     False        False
# ...        ...       ...          ...
# 998548   False     False        False
# 998549   False     False        False
# 998550   False     False        False
# 998551   False     False        False
# 998552   False     False        False
#
# [998553 rows x 46 columns]

# %%
df.fillna(0) # Fill all the NULL cells with 0
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0            1.0  1.528089e+09     e          1.0   tcp           1.0
# 1            2.0  1.528089e+09     e          1.0   arp           2.0
# 2            3.0  1.528089e+09     e          1.0   UDP           1.0
# 3            4.0  1.528089e+09     i          1.0   tcp           1.0
# 4            5.0  1.528089e+09     e          1.0   UDP           1.0
# ...          ...           ...   ...          ...   ...           ...
# 998548  998549.0  1.528085e+09     e          1.0   udp           3.0
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# 998551  998552.0  1.528085e+09     e          1.0   udp           3.0
# 998552  998553.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr  sport            daddr dport  ...  \
# 0       192.168.100.147  49960    192.168.100.7    80  ...
# 1         192.168.100.7     -1  192.168.100.147    -1  ...
# 2       192.168.100.147  49962    192.168.100.7    80  ...
# 3       192.168.100.147  49964    192.168.100.7    80  ...
# 4       192.168.100.147  49966    192.168.100.7    80  ...
# ...                 ...    ...              ...   ...  ...
# 998548  192.168.100.149  24881    192.168.100.5    80  ...
# 998549  192.168.100.149  24882    192.168.100.5    80  ...
# 998550  192.168.100.149  24883    192.168.100.5    80  ...
# 998551  192.168.100.149  24884    192.168.100.5    80  ...
# 998552  192.168.100.149  24885    192.168.100.5    80  ...
#
#         AR_P_Proto_P_DstIP  N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  \
# 0                 1.127040               96.0              75.0
# 1             15267.200000                1.0               2.0
# 2                 1.127040               96.0              75.0
# 3                 1.127040               96.0              75.0
# 4                 1.127040               96.0              75.0
# ...                    ...                ...               ...
# 998548            0.269102              100.0             100.0
# 998549            0.269102              100.0             100.0
# 998550            0.269102              100.0             100.0
# 998551            0.269102              100.0             100.0
# 998552            0.269102              100.0             100.0
#
#         AR_P_Proto_P_Sport  AR_P_Proto_P_Dport  \
# 0                 1.133720            1.129970
# 1                 0.005142            0.005142
# 2                 1.135100            1.129970
# 3                 1.135140            1.129970
# 4                 1.135260            1.129970
# ...                    ...                 ...
# 998548            0.269107            0.269102
# 998549            0.269107            0.269102
# 998550            0.269107            0.269102
# 998551            0.269107            0.269102
# 998552            0.269107            0.269102
#
#         Pkts_P_State_P_Protocol_P_DestIP  Pkts_P_State_P_Protocol_P_SrcIP  \
# 0                                  770.0                            602.0
# 1                                    2.0                              6.0
# 2                                  770.0                            602.0
# 3                                  770.0                            602.0
# 4                                  770.0                            602.0
# ...                                  ...                              ...
# 998548                             700.0                            700.0
# 998549                             700.0                            700.0
# 998550                             700.0                            700.0
# 998551                             700.0                            700.0
# 998552                             700.0                            700.0
#
#         attack  category  subcategory
# 0          1.0       DoS         HTTP
# 1          1.0       DoS         HTTP
# 2          1.0       DoS         HTTP
# 3          1.0       DoS         HTTP
# 4          1.0       DoS         HTTP
# ...        ...       ...          ...
# 998548     1.0       DoS          UDP
# 998549     1.0       DoS          UDP
# 998550     1.0       DoS          UDP
# 998551     1.0       DoS          UDP
# 998552     1.0       DoS          UDP
#
# [998553 rows x 46 columns]

# %% [markdown]
# ### q4

# %%
sns.boxplot(df['pkts'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print(np.where(df['pkts']>15)) #positions of outliers
# Out:
# (array([   841,    857,    858,    859,    870,    871,   1100,   1412,
#          1413,   1415,   3171, 168701, 270563, 278898, 528261, 616536,
#        618665, 632279, 651644, 654683, 875344, 918882, 948049, 958610,
#        962259]),)

# %%
sns.boxplot(df['sbytes'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print(np.where(df['sbytes']>100)) #positions of outliers
# Out:
# (array([     0,      2,      3, ..., 998550, 998551, 998552]),)

# %% [markdown]
# ### q5

# %%
print(df['rate'].corr(df['srate']))
# Out:
# 0.18904714981030551

# %% [markdown]
# ### q6

# %%
df.describe()
# Out:
#              pkSeqID         stime    flgs_number   proto_number  \
# count  996297.000000  9.962970e+05  996297.000000  996294.000000
# mean   500191.103927  1.528083e+09       1.808430       1.765398
# std    287942.231266  1.754173e+03       1.107501       0.972087
# min         1.000000  1.528081e+09       1.000000       1.000000
# 25%    251331.000000  1.528081e+09       1.000000       1.000000
# 50%    500405.000000  1.528081e+09       2.000000       1.000000
# 75%    749479.000000  1.528085e+09       2.000000       3.000000
# max    998553.000000  1.528089e+09       6.000000       4.000000
#
#                 pkts          bytes   state_number         ltime  \
# count  996297.000000  996297.000000  996297.000000  9.962970e+05
# mean        6.520403     614.684976       2.826334  1.528083e+09
# std         8.634993     605.434762       1.210459  1.752839e+03
# min         1.000000     120.000000       1.000000  1.528081e+09
# 25%         5.000000     462.000000       1.000000  1.528081e+09
# 50%         6.000000     616.000000       3.000000  1.528081e+09
# 75%         8.000000     770.000000       4.000000  1.528085e+09
# max      5886.000000  412020.000000       5.000000  1.528090e+09
#
#                  seq            dur  ...  TnP_Per_Dport  AR_P_Proto_P_SrcIP  \
# count  996297.000000  996297.000000  ...  996297.000000       996297.000000
# mean   114587.944475      27.115614  ...     650.382948            1.586263
# std     75872.879322      11.633506  ...     250.475791           28.424912
# min         1.000000       0.000000  ...       2.000000            0.003857
# 25%     49526.000000      24.027264  ...     500.000000            0.177890
# 50%    101864.000000      26.371984  ...     600.000000            0.232549
# 75%    179137.000000      30.317171  ...     782.000000            0.340498
# max    262212.000000    1555.683960  ...    5886.000000        15748.000000
#
#        AR_P_Proto_P_DstIP  N_IN_Conn_P_DstIP  N_IN_Conn_P_SrcIP  \
# count       996297.000000      996297.000000      996297.000000
# mean             1.591356          83.367601          83.344421
# std             28.710936          23.692729          23.707796
# min              0.003857           1.000000           1.000000
# 25%              0.177890          70.000000          70.000000
# 50%              0.232549         100.000000         100.000000
# 75%              0.340498         100.000000         100.000000
# max          15267.200000         100.000000         100.000000
#
#        AR_P_Proto_P_Sport  AR_P_Proto_P_Dport  \
# count       996297.000000       996297.000000
# mean             1.589005            1.256640
# std             23.887935           22.312290
# min              0.000000            0.005142
# 25%              0.171433            0.179636
# 50%              0.237190            0.231424
# 75%              0.340519            0.340938
# max          13245.000000        13245.000000
#
#        Pkts_P_State_P_Protocol_P_DestIP  Pkts_P_State_P_Protocol_P_SrcIP  \
# count                     996297.000000                    996297.000000
# mean                         488.192833                       487.989795
# std                          296.422287                       296.309507
# min                            1.000000                         1.000000
# 25%                          286.000000                       286.000000
# 50%                          400.000000                       400.000000
# 75%                          600.000000                       600.000000
# max                         5886.000000                      5886.000000
#
#          attack
# count  996297.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
#
# [8 rows x 37 columns]

# %% [markdown]
# ### q7

# %%
df.head(3)
# Out:
#    pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0      1.0  1.528089e+09     e          1.0   tcp           1.0
# 1      2.0  1.528089e+09     e          1.0   arp           2.0
# 2      3.0  1.528089e+09     e          1.0   UDP           1.0
#
#              saddr  sport            daddr dport  ...  AR_P_Proto_P_DstIP  \
# 0  192.168.100.147  49960    192.168.100.7    80  ...             1.12704
# 1    192.168.100.7     -1  192.168.100.147    -1  ...         15267.20000
# 2  192.168.100.147  49962    192.168.100.7    80  ...             1.12704
#
#    N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 0               96.0              75.0            1.133720
# 1                1.0               2.0            0.005142
# 2               96.0              75.0            1.135100
#
#    AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 0            1.129970                             770.0
# 1            0.005142                               2.0
# 2            1.129970                             770.0
#
#    Pkts_P_State_P_Protocol_P_SrcIP  attack  category  subcategory
# 0                            602.0     1.0       DoS         HTTP
# 1                              6.0     1.0       DoS         HTTP
# 2                            602.0     1.0       DoS         HTTP
#
# [3 rows x 46 columns]

# %% [markdown]
# ### q8

# %%
df.tail(4)
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# 998551  998552.0  1.528085e+09     e          1.0   udp           3.0
# 998552  998553.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr  sport          daddr dport  ...  AR_P_Proto_P_DstIP  \
# 998549  192.168.100.149  24882  192.168.100.5    80  ...            0.269102
# 998550  192.168.100.149  24883  192.168.100.5    80  ...            0.269102
# 998551  192.168.100.149  24884  192.168.100.5    80  ...            0.269102
# 998552  192.168.100.149  24885  192.168.100.5    80  ...            0.269102
#
#         N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 998549              100.0             100.0            0.269107
# 998550              100.0             100.0            0.269107
# 998551              100.0             100.0            0.269107
# 998552              100.0             100.0            0.269107
#
#         AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 998549            0.269102                             700.0
# 998550            0.269102                             700.0
# 998551            0.269102                             700.0
# 998552            0.269102                             700.0
#
#         Pkts_P_State_P_Protocol_P_SrcIP  attack  category  subcategory
# 998549                            700.0     1.0       DoS          UDP
# 998550                            700.0     1.0       DoS          UDP
# 998551                            700.0     1.0       DoS          UDP
# 998552                            700.0     1.0       DoS          UDP
#
# [4 rows x 46 columns]

# %% [markdown]
# ### q9

# %%
df.loc[df.proto=="UDP"].head(1)
# Out:
#    pkSeqID         stime flags  flgs_number proto  proto_number  \
# 2      3.0  1.528089e+09     e          1.0   UDP           1.0
#
#              saddr  sport          daddr dport  ...  AR_P_Proto_P_DstIP  \
# 2  192.168.100.147  49962  192.168.100.7    80  ...             1.12704
#
#    N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 2               96.0              75.0              1.1351
#
#    AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 2             1.12997                             770.0
#
#    Pkts_P_State_P_Protocol_P_SrcIP  attack  category  subcategory
# 2                            602.0     1.0       DoS         HTTP
#
# [1 rows x 46 columns]

# %% [markdown]
# ### q10

# %%
len(df)
# Out:
# 998553

# %% [markdown]
# ### q11

# %%
df.iloc[:1, :5]
# Out:
#    pkSeqID         stime flags  flgs_number proto
# 0      1.0  1.528089e+09     e          1.0   tcp

# %% [markdown]
# ### q12

# %%
df.loc[df["flags"]=='i']["pkts"].sum()
# Out:
# 240.0

# %% [markdown]
# ### q13

# %%
g1=df.loc[df.pkts<=10]
g2=df.loc[df.pkts>10]
display(g1,g2)
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0            1.0  1.528089e+09     e          1.0   tcp           1.0
# 1            2.0  1.528089e+09     e          1.0   arp           2.0
# 2            3.0  1.528089e+09     e          1.0   UDP           1.0
# 3            4.0  1.528089e+09     i          1.0   tcp           1.0
# 4            5.0  1.528089e+09     e          1.0   UDP           1.0
# ...          ...           ...   ...          ...   ...           ...
# 998548  998549.0  1.528085e+09     e          1.0   udp           3.0
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# 998551  998552.0  1.528085e+09     e          1.0   udp           3.0
# 998552  998553.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr  sport            daddr dport  ...  \
# 0       192.168.100.147  49960    192.168.100.7    80  ...
# 1         192.168.100.7     -1  192.168.100.147    -1  ...
# 2       192.168.100.147  49962    192.168.100.7    80  ...
# 3       192.168.100.147  49964    192.168.100.7    80  ...
# 4       192.168.100.147  49966    192.168.100.7    80  ...
# ...                 ...    ...              ...   ...  ...
# 998548  192.168.100.149  24881    192.168.100.5    80  ...
# 998549  192.168.100.149  24882    192.168.100.5    80  ...
# 998550  192.168.100.149  24883    192.168.100.5    80  ...
# 998551  192.168.100.149  24884    192.168.100.5    80  ...
# 998552  192.168.100.149  24885    192.168.100.5    80  ...
#
#         AR_P_Proto_P_DstIP  N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  \
# 0                 1.127040               96.0              75.0
# 1             15267.200000                1.0               2.0
# 2                 1.127040               96.0              75.0
# 3                 1.127040               96.0              75.0
# 4                 1.127040               96.0              75.0
# ...                    ...                ...               ...
# 998548            0.269102              100.0             100.0
# 998549            0.269102              100.0             100.0
# 998550            0.269102              100.0             100.0
# 998551            0.269102              100.0             100.0
# 998552            0.269102              100.0             100.0
#
#         AR_P_Proto_P_Sport  AR_P_Proto_P_Dport  \
# 0                 1.133720            1.129970
# 1                 0.005142            0.005142
# 2                 1.135100            1.129970
# 3                 1.135140            1.129970
# 4                 1.135260            1.129970
# ...                    ...                 ...
# 998548            0.269107            0.269102
# 998549            0.269107            0.269102
# 998550            0.269107            0.269102
# 998551            0.269107            0.269102
# 998552            0.269107            0.269102
#
#         Pkts_P_State_P_Protocol_P_DestIP  Pkts_P_State_P_Protocol_P_SrcIP  \
# 0                                  770.0                            602.0
# 1                                    2.0                              6.0
# 2                                  770.0                            602.0
# 3                                  770.0                            602.0
# 4                                  770.0                            602.0
# ...                                  ...                              ...
# 998548                             700.0                            700.0
# 998549                             700.0                            700.0
# 998550                             700.0                            700.0
# 998551                             700.0                            700.0
# 998552                             700.0                            700.0
#
#         attack  category  subcategory
# 0          1.0       DoS         HTTP
# 1          1.0       DoS         HTTP
# 2          1.0       DoS         HTTP
# 3          1.0       DoS         HTTP
# 4          1.0       DoS         HTTP
# ...        ...       ...          ...
# 998548     1.0       DoS          UDP
# 998549     1.0       DoS          UDP
# 998550     1.0       DoS          UDP
# 998551     1.0       DoS          UDP
# 998552     1.0       DoS          UDP
#
# [875049 rows x 46 columns]
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 144        145.0  1.528089e+09   e s          2.0   tcp           1.0
# 276        277.0  1.528089e+09   e s          2.0   tcp           1.0
# 277        278.0  1.528089e+09   e s          2.0   UDP           1.0
# 278        279.0  1.528089e+09   e s          2.0   UDP           1.0
# 283        284.0  1.528089e+09   e s          2.0   tcp           1.0
# ...          ...           ...   ...          ...   ...           ...
# 998213  998214.0  1.528085e+09     e          1.0   udp           3.0
# 998214  998215.0  1.528085e+09     e          1.0   udp           3.0
# 998215  998216.0  1.528085e+09     e          1.0   udp           3.0
# 998216  998217.0  1.528085e+09     e          1.0   udp           3.0
# 998217  998218.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr  sport          daddr dport  ...  AR_P_Proto_P_DstIP  \
# 144     192.168.100.148  51962  192.168.100.7    80  ...            1.096110
# 276     192.168.100.149  52812  192.168.100.3    80  ...            1.240990
# 277     192.168.100.149  52814  192.168.100.3    80  ...            1.240990
# 278     192.168.100.149  52816  192.168.100.3    80  ...            1.240990
# 283     192.168.100.149  52820  192.168.100.3    80  ...            1.240990
# ...                 ...    ...            ...   ...  ...                 ...
# 998213  192.168.100.150  57478  192.168.100.3    80  ...            0.483652
# 998214  192.168.100.150  57479  192.168.100.3    80  ...            0.483652
# 998215  192.168.100.150  57480  192.168.100.3    80  ...            0.483652
# 998216  192.168.100.150  57481  192.168.100.3    80  ...            0.483652
# 998217  192.168.100.150  57482  192.168.100.3    80  ...            0.483652
#
#         N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 144                  46.0              46.0            1.615570
# 276                  90.0              76.0            2.012510
# 277                  90.0              76.0            1.581320
# 278                  90.0              76.0            1.725150
# 283                  90.0              76.0            2.239860
# ...                   ...               ...                 ...
# 998213               18.0              18.0            0.483652
# 998214               18.0              18.0            0.483652
# 998215               18.0              18.0            0.483652
# 998216               18.0              18.0            0.483652
# 998217               18.0              18.0            0.483652
#
#         AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 144               1.135480                             375.0
# 276               1.278180                             754.0
# 277               1.278180                             754.0
# 278               1.278180                             754.0
# 283               1.278180                             754.0
# ...                    ...                               ...
# 998213            0.351218                             234.0
# 998214            0.351218                             234.0
# 998215            0.351218                             234.0
# 998216            0.351218                             234.0
# 998217            0.351218                             234.0
#
#         Pkts_P_State_P_Protocol_P_SrcIP  attack  category  subcategory
# 144                               375.0     1.0       DoS         HTTP
# 276                               628.0     1.0       DoS         HTTP
# 277                               628.0     1.0       DoS         HTTP
# 278                               628.0     1.0       DoS         HTTP
# 283                               628.0     1.0       DoS         HTTP
# ...                                 ...     ...       ...          ...
# 998213                            234.0     1.0       DoS          UDP
# 998214                            234.0     1.0       DoS          UDP
# 998215                            234.0     1.0       DoS          UDP
# 998216                            234.0     1.0       DoS          UDP
# 998217                            234.0     1.0       DoS          UDP
#
# [121248 rows x 46 columns]

# %%
display(g1.describe(),g2.describe())
# Out:
#              pkSeqID         stime    flgs_number   proto_number  \
# count  875049.000000  8.750490e+05  875049.000000  875046.000000
# mean   453665.730100  1.528082e+09       1.919802       1.594910
# std    273994.691266  1.654238e+03       1.136818       0.914261
# min         1.000000  1.528081e+09       1.000000       1.000000
# 25%    221077.000000  1.528081e+09       1.000000       1.000000
# 50%    439841.000000  1.528081e+09       2.000000       1.000000
# 75%    661055.000000  1.528085e+09       2.000000       3.000000
# max    998553.000000  1.528089e+09       6.000000       3.000000
#
#                 pkts          bytes   state_number         ltime  \
# count  875049.000000  875049.000000  875049.000000  8.750490e+05
# mean        5.763201     599.805765       2.664259  1.528082e+09
# std         1.836620     195.968509       1.204595  1.652752e+03
# min         1.000000     120.000000       1.000000  1.528081e+09
# 25%         5.000000     420.000000       1.000000  1.528081e+09
# 50%         6.000000     616.000000       3.000000  1.528081e+09
# 75%         7.000000     770.000000       4.000000  1.528085e+09
# max        10.000000    3066.000000       4.000000  1.528090e+09
#
#                  seq            dur  ...  TnP_Per_Dport  AR_P_Proto_P_SrcIP  \
# count  875049.000000  875049.000000  ...  875049.000000       875049.000000
# mean   116941.212148      27.190257  ...     584.825132            1.743525
# std     77266.267429      12.390290  ...     183.338841           30.325485
# min         1.000000       0.000000  ...       2.000000            0.003857
# 25%     49614.000000      23.589230  ...     479.000000            0.167220
# 50%    104879.000000      26.063435  ...     569.000000            0.219420
# 75%    183830.000000      31.011560  ...     665.000000            0.290801
# max    262212.000000    1555.683960  ...    1295.000000        15748.000000
#
#        AR_P_Proto_P_DstIP  N_IN_Conn_P_DstIP  N_IN_Conn_P_SrcIP  \
# count       875049.000000      875049.000000      875049.000000
# mean             1.749324          83.447846          83.422086
# std             30.630701          23.668052          23.684302
# min              0.003857           1.000000           1.000000
# 25%              0.167220          70.000000          70.000000
# 50%              0.219420         100.000000         100.000000
# 75%              0.290801         100.000000         100.000000
# max          15267.200000         100.000000         100.000000
#
#        AR_P_Proto_P_Sport  AR_P_Proto_P_Dport  \
# count       875049.000000       875049.000000
# mean             1.746598            1.371111
# std             25.483436           23.803780
# min              0.000000            0.005142
# 25%              0.163702            0.171312
# 50%              0.221926            0.217974
# 75%              0.291395            0.302580
# max          13245.000000        13245.000000
#
#        Pkts_P_State_P_Protocol_P_DestIP  Pkts_P_State_P_Protocol_P_SrcIP  \
# count                     875049.000000                    875049.000000
# mean                         419.717112                       419.491779
# std                          223.051071                       222.809689
# min                            1.000000                         1.000000
# 25%                          270.000000                       270.000000
# 50%                          372.000000                       372.000000
# 75%                          546.000000                       546.000000
# max                         1082.000000                      1082.000000
#
#          attack
# count  875049.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
#
# [8 rows x 37 columns]
#              pkSeqID         stime    flgs_number   proto_number  \
# count  121248.000000  1.212480e+05  121248.000000  121248.000000
# mean   835965.564884  1.528085e+09       1.004652       2.995802
# std    105397.376955  1.653642e+02       0.126993       0.092297
# min       145.000000  1.528081e+09       1.000000       1.000000
# 25%    744142.750000  1.528085e+09       1.000000       3.000000
# 50%    836815.500000  1.528085e+09       1.000000       3.000000
# 75%    927420.250000  1.528085e+09       1.000000       3.000000
# max    998218.000000  1.528089e+09       6.000000       4.000000
#
#                 pkts          bytes   state_number         ltime  \
# count  121248.000000  121248.000000  121248.000000  1.212480e+05
# mean       11.985146     722.068512       3.996033  1.528085e+09
# std        23.544528    1649.754250       0.098195  1.642364e+02
# min        11.000000     660.000000       1.000000  1.528081e+09
# 25%        11.000000     660.000000       4.000000  1.528085e+09
# 50%        12.000000     720.000000       4.000000  1.528085e+09
# 75%        12.000000     720.000000       4.000000  1.528085e+09
# max      5886.000000  412020.000000       5.000000  1.528089e+09
#
#                  seq            dur  ...  TnP_Per_Dport  AR_P_Proto_P_SrcIP  \
# count  121248.000000  121248.000000  ...  121248.000000       121248.000000
# mean    97604.369293      26.576912  ...    1123.514887            0.451302
# std     62356.517433       1.948570  ...     134.396017            0.813511
# min         1.000000       3.885272  ...      17.000000            0.085599
# 25%     48694.750000      25.320789  ...    1070.000000            0.428751
# 50%     89288.500000      26.858641  ...    1112.000000            0.441397
# 75%    140111.250000      27.213820  ...    1200.000000            0.469416
# max    258070.000000      62.429565  ...    5886.000000          200.822000
#
#        AR_P_Proto_P_DstIP  N_IN_Conn_P_DstIP  N_IN_Conn_P_SrcIP  \
# count       121248.000000      121248.000000      121248.000000
# mean             0.451300          82.788475          82.783914
# std              0.813503          23.862170          23.869277
# min              0.085599           1.000000           1.000000
# 25%              0.428751          70.000000          70.000000
# 50%              0.441397          98.000000          98.000000
# 75%              0.469416         100.000000         100.000000
# max            200.822000         100.000000         100.000000
#
#        AR_P_Proto_P_Sport  AR_P_Proto_P_Dport  \
# count       121248.000000       121248.000000
# mean             0.451652            0.430506
# std              0.813567            0.814316
# min              0.184839            0.078237
# 25%              0.429252            0.409628
# 50%              0.441426            0.433510
# 75%              0.469820            0.454642
# max            200.822000          200.822000
#
#        Pkts_P_State_P_Protocol_P_DestIP  Pkts_P_State_P_Protocol_P_SrcIP  \
# count                     121248.000000                    121248.000000
# mean                         982.383347                       982.341210
# std                          291.332284                       291.411775
# min                           11.000000                        11.000000
# 25%                          814.000000                       814.000000
# 50%                         1100.000000                      1100.000000
# 75%                         1200.000000                      1200.000000
# max                         5886.000000                      5886.000000
#
#          attack
# count  121248.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
#
# [8 rows x 37 columns]

# %%
# (a) Average packets for a given stime
g1.groupby("stime").pkts.mean()
# Out:
# stime
# 1.528081e+09     5.110172
# 1.528081e+09     5.392040
# 1.528081e+09     5.370576
# 1.528081e+09     5.133389
# 1.528081e+09     4.801621
#                   ...
# 1.528089e+09     9.250000
# 1.528089e+09     8.222222
# 1.528089e+09     8.000000
# 1.528089e+09    10.000000
# 1.528089e+09    10.000000
# Name: pkts, Length: 96, dtype: float64

# %%
#  (b) Average sbytes for a given stime
g1.groupby("stime").sbytes.mean()
# Out:
# stime
# 1.528081e+09     686.052822
# 1.528081e+09     658.272526
# 1.528081e+09     651.063572
# 1.528081e+09     619.102752
# 1.528081e+09     582.624001
#                    ...
# 1.528089e+09    1104.500000
# 1.528089e+09     791.444444
# 1.528089e+09     768.812500
# 1.528089e+09     846.498195
# 1.528089e+09     847.029412
# Name: sbytes, Length: 96, dtype: float64

# %%
# (c) Average dbytes for a given stime
g1.groupby("stime").dbytes.mean()
# Out:
# stime
# 1.528081e+09      33.104427
# 1.528081e+09      51.930759
# 1.528081e+09      53.271446
# 1.528081e+09      51.975846
# 1.528081e+09      46.395426
#                    ...
# 1.528089e+09    1330.000000
# 1.528089e+09    1337.333333
# 1.528089e+09     700.000000
# 1.528089e+09     766.000000
# 1.528089e+09    1396.000000
# Name: dbytes, Length: 96, dtype: float64

# %% [markdown]
# ### q14

# %%
print(df.groupby("subcategory").Pkts_P_State_P_Protocol_P_DestIP.mean())
print(df.groupby("subcategory").Pkts_P_State_P_Protocol_P_DestIP.var())
# Out:
# subcategory
# HTTP    746.097643
# TCP     329.842411
# UDP     742.008949
# Name: Pkts_P_State_P_Protocol_P_DestIP, dtype: float64
# subcategory
# HTTP    60446.448007
# TCP     21456.481203
# UDP     89808.333377
# Name: Pkts_P_State_P_Protocol_P_DestIP, dtype: float64

# %% [markdown]
# ### q15

# %%
sns.distplot(df['stime'],bins=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df["stime"].skew()
# Out:
# 0.5079005557421301
